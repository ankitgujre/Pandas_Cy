# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_csv("myfile.csv")
dt
# Out:
#    RNO       Name Course
# 0    1     Sunday   Java
# 1    2     Monday    Sql
# 2    3    Tuesday     DS
# 3    4  Wednesday    DSA
# 4    5   Thursday    Sql
# 5    6     Friday     DS
# 6    7   Saturday    DSA

# %%
print(dt)
# Out:
#    RNO       Name Course
# 0    1     Sunday   Java
# 1    2     Monday    Sql
# 2    3    Tuesday     DS
# 3    4  Wednesday    DSA
# 4    5   Thursday    Sql
# 5    6     Friday     DS
# 6    7   Saturday    DSA
