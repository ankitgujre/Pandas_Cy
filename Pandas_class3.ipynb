# %%
import numpy as np
import pandas as pd

# %%
# Methods

# %%
s = ["Amit","Ankit","Sumit","Harsh","Devendra","Bittu","Ashu","Ajay","Aryan","Birendra","Ankit","Amit","Sumit"]
students = pd.Series(s)
print(students)
# Out:
# 0         Amit
# 1        Ankit
# 2        Sumit
# 3        Harsh
# 4     Devendra
# 5        Bittu
# 6         Ashu
# 7         Ajay
# 8        Aryan
# 9     Birendra
# 10       Ankit
# 11        Amit
# 12       Sumit
# dtype: object

# %%
print(students.head())  # head() FUNCTION  by default showing 5
# Out:
# 0        Amit
# 1       Ankit
# 2       Sumit
# 3       Harsh
# 4    Devendra
# dtype: object

# %%
students.head(7)
# Out:
# 0        Amit
# 1       Ankit
# 2       Sumit
# 3       Harsh
# 4    Devendra
# 5       Bittu
# 6        Ashu
# dtype: object

# %%
print(students.tail())  # tail() FUNCTION  by default showing 5
# Out:
# 8        Aryan
# 9     Birendra
# 10       Ankit
# 11        Amit
# 12       Sumit
# dtype: object

# %%
print(students.tail(3))
# Out:
# 10    Ankit
# 11     Amit
# 12    Sumit
# dtype: object

# %%
print(students.sample())   # return only single value random value
# Out:
# 6    Ashu
# dtype: object

# %%
print(students.sample(5))
# Out:
# 3        Harsh
# 10       Ankit
# 2        Sumit
# 12       Sumit
# 9     Birendra
# dtype: object

# %%
print(students.value_counts())
# Out:
# Amit        2
# Ankit       2
# Sumit       2
# Harsh       1
# Devendra    1
# Bittu       1
# Ashu        1
# Ajay        1
# Aryan       1
# Birendra    1
# Name: count, dtype: int64

# %%
print(students.sort_values())  # display data values in ascending order
# Out:
# 7         Ajay
# 0         Amit
# 11        Amit
# 1        Ankit
# 10       Ankit
# 8        Aryan
# 6         Ashu
# 9     Birendra
# 5        Bittu
# 4     Devendra
# 3        Harsh
# 2        Sumit
# 12       Sumit
# dtype: object

# %%
print(students.sort_values(ascending = False))
# Out:
# 2        Sumit
# 12       Sumit
# 3        Harsh
# 4     Devendra
# 5        Bittu
# 9     Birendra
# 6         Ashu
# 8        Aryan
# 1        Ankit
# 10       Ankit
# 0         Amit
# 11        Amit
# 7         Ajay
# dtype: object

# %%
print(students.sort_index(ascending = False))
# Out:
# 12       Sumit
# 11        Amit
# 10       Ankit
# 9     Birendra
# 8        Aryan
# 7         Ajay
# 6         Ashu
# 5        Bittu
# 4     Devendra
# 3        Harsh
# 2        Sumit
# 1        Ankit
# 0         Amit
# dtype: object

# %%
print(students.sort_index())
# Out:
# 0         Amit
# 1        Ankit
# 2        Sumit
# 3        Harsh
# 4     Devendra
# 5        Bittu
# 6         Ashu
# 7         Ajay
# 8        Aryan
# 9     Birendra
# 10       Ankit
# 11        Amit
# 12       Sumit
# dtype: object

# %%
print(students.values)
# Out:
# ['Amit' 'Ankit' 'Sumit' 'Harsh' 'Devendra' 'Bittu' 'Ashu' 'Ajay' 'Aryan'
#  'Birendra' 'Ankit' 'Amit' 'Sumit']

# %%
ind = students.sort_index()
val = students.sort_values()
print(ind)
print()
print(val)
# Out:
# 0         Amit
# 1        Ankit
# 2        Sumit
# 3        Harsh
# 4     Devendra
# 5        Bittu
# 6         Ashu
# 7         Ajay
# 8        Aryan
# 9     Birendra
# 10       Ankit
# 11        Amit
# 12       Sumit
# dtype: object
#
# 7         Ajay
# 0         Amit
# 11        Amit
# 1        Ankit
# 10       Ankit
# 8        Aryan
# 6         Ashu
# 9     Birendra
# 5        Bittu
# 4     Devendra
# 3        Harsh
# 2        Sumit
# 12       Sumit
# dtype: object

# %%
# concept of chaning
print(students.sort_values().head(3).values)
# Out:
# ['Ajay' 'Amit' 'Amit']

# %%
palindrom = "MoM"
s = pd.Series(list(palindrom.lower()))

if s.equals(s[::-1]):
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Not Palindrome
