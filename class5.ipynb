# %%
import numpy as np
import pandas as pd

# %%
A = [10,3,56,47,8]
s = pd.Series(A)
print(s)
# Out:
# 0    10
# 1     3
# 2    56
# 3    47
# 4     8
# dtype: int64

# %%
print(4 in s)
# Out:
# True

# %%
# Membership operator
print(4 in s.values)
# Out:
# False

# %%
# Arithmetic operator
# (+,-,/,*)
# print(s+20)

# %%
# print(s - 20)

# %%
# p = s.values 10
# print(p.values)
print(s[s > 10])  # input masking
# Out:
# 2    56
# 3    47
# dtype: int64

# %%
print(s[s > 10].values)
# Out:
# [56 47]

# %%
print(s[s > 10].index)
# Out:
# Index([2, 3], dtype='int64')

# %%
A = [10,3,2,56,47,8, 10]
print(s[s >= 10].size)
print(s[s > 10].value_counts())
# Out:
# 3
# 56    1
# 47    1
# Name: count, dtype: int64

# %%
print(s[s >= 10].min())
# Out:
# 10

# %%
print(s[s >= 10].sort_values(ascending = False))
# Out:
# 2    56
# 3    47
# 0    10
# dtype: int64

# %%
print(sorted(s[s>10])[::-1])
# Out:
# [56, 47]

# %%
s.plot(kind = 'pie')
# Out:
# <Axes: >
