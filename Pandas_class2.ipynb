# %%
import numpy as np
import pandas as pd

# %%
# Attributes

# %%
Name = ["Anubhav", "Rakesh", "Piyush", "Rohan", "Mini"]
# Name = ["Anubhav", "Rakesh", "Piyush", "Rohan", "Anubhav"]
s = pd.Series(Name)
print(s)
# Out:
# 0    Anubhav
# 1     Rakesh
# 2     Piyush
# 3      Rohan
# 4       Mini
# dtype: object

# %%
Result = ["Pass", "Fail", "Pass", "Pass", "Pass"]
R = pd.Series(Result)
print(R)
print(Result)
print(R.is_unique)
print(R.index)
# Out:
# 0    Pass
# 1    Fail
# 2    Pass
# 3    Pass
# 4    Pass
# dtype: object
# ['Pass', 'Fail', 'Pass', 'Pass', 'Pass']
# False
# RangeIndex(start=0, stop=5, step=1)

# %%
R = pd.Series(Result, index = Name, name = "Pandas_Class2")
print(R)
print(R.index)
# Out:
# Anubhav    Pass
# Rakesh     Fail
# Piyush     Pass
# Rohan      Pass
# Mini       Pass
# Name: Pandas_Class2, dtype: object
# Index(['Anubhav', 'Rakesh', 'Piyush', 'Rohan', 'Mini'], dtype='object')

# %%
print(R.size)
# Out:
# 5

# %%
print(R.dtype)
# Out:
# object

# %%
print(R.name)
# Out:
# Pandas_Class2

# %%
print(R.is_unique)
# Out:
# False

# %%
print(s.is_unique)
# Out:
# True

# %%
print(R.values)
# Out:
# ['Pass' 'Fail' 'Pass' 'Pass' 'Pass']

# %%
print(R.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Methods

# %%
data = pd.read_csv("pandas_practice_dataset.csv")
print(data)
s = data['name']
print(s)
# Out:
#    student_id    name  age       city            course   fees
# 0         101   Aarav   21     Bhopal            Python   8500
# 1         102    Diya   22     Indore              Java   9200
# 2         103   Rohan   20    Gwalior     Data Analysis   7800
# 3         104  Ananya   23      Delhi          Power BI  10000
# 4         105   Kabir   21       Pune            Python   8900
# 5         106   Meera   22     Jaipur               SQL   7600
# 6         107  Vivaan   24     Mumbai             Excel   9800
# 7         108    Isha   20     Bhopal           Tableau   8700
# 8         109   Arjun   23  Hyderabad            Python   9400
# 9         110    Siya   21     Indore  Machine Learning  11000
# 0     Aarav
# 1      Diya
# 2     Rohan
# 3    Ananya
# 4     Kabir
# 5     Meera
# 6    Vivaan
# 7      Isha
# 8     Arjun
# 9      Siya
# Name: name, dtype: object
